# %% [markdown]
# <a href="https://colab.research.google.com/github/ROrodrigp/ProgramacionCienciaDatos/blob/main/Histogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
url = 'https://bit.ly/2cLzoxH'
brecha = pd.read_csv(url)
brecha
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
brecha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
brecha.lifeExp.hist(bins=50)

# %%
#Se pueden cambiar los parametros 
brecha.lifeExp.hist(bins=100, grid=False, xlabelsize=12, ylabelsize=12)
plt.title( 'Histograma de pandas',fontsize=15)
plt.xlabel('Esperanza de vida',fontsize=14)
plt.ylabel('Frecuencia',fontsize=14)
plt.show()

# %%
brecha.gdpPercap.hist(bins=100, grid=False)
plt.title( 'Histograma de pandas',fontsize=15)
plt.xlabel('Ingreso per capita',fontsize=14)
plt.ylabel('Frecuencia',fontsize=14)
plt.show()

# %%
brecha.gdpPercap.hist(bins=1000, grid=False)
plt.title( 'Histograma de pandas',fontsize=15)
plt.xlabel('Ingreso per capita',fontsize=14)
plt.ylabel('Frecuencia',fontsize=14)
plt.xscale('log')
plt.show()

# %%
import seaborn as sns

# %%
#Grafica de distribución acumulativa 
sns.distplot(brecha.lifeExp)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(brecha.lifeExp, color='green', kde=True, bins=100)
plt.title( 'Histograma de seaborn',fontsize=15)
plt.xlabel('Esperanza de vida',fontsize=14)
plt.ylabel('Frecuencia',fontsize=14)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Comparando la brecha de esperanza de vida enatre dos países
df = brecha[brecha.continent == 'Africa']
sns.distplot(df.lifeExp, label='Africa')
df = brecha[brecha.continent== 'Americas']
sns.distplot(df.lifeExp, label='Americas')
plt.title( 'Histograma de seaborn',fontsize=15)
plt.xlabel('Esperanza de vida',fontsize=14)
plt.ylabel('Frecuencia',fontsize=14)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df = brecha[brecha.continent == 'Africa']
sns.distplot(df.lifeExp, label='Africa',hist=False)
df = brecha[brecha.continent== 'Americas']
sns.distplot(df.lifeExp, label='Americas', hist=False)
plt.title( 'Histograma de seaborn',fontsize=15)
plt.xlabel('Esperanza de vida',fontsize=14)
plt.ylabel('Frecuencia',fontsize=14)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plt.style.use('seaborn-white')
data = np.random.randn(1000)
plt.hist(data)
# Out:
# (array([  1.,  16.,  69., 202., 252., 275., 144.,  34.,   5.,   2.]),
#  array([-3.75722763, -2.97905771, -2.20088779, -1.42271787, -0.64454794,
#          0.13362198,  0.9117919 ,  1.68996182,  2.46813175,  3.24630167,
#          4.02447159]),
#  <a list of 10 Patch objects>)

# %%
#Creamos tres conjuntos con distribución normal y los comparamos 
x = np.random.normal(0,0.7,1000)
y = np.random.normal(2,1.5,1000)
z = np.random.normal(-3,1,1000)

dic = dict(histtype='stepfilled',alpha=0.5,bins=50)
plt.hist(x,**dic)
plt.hist(y,**dic)
plt.hist(z,**dic)

plt.show()

# %%
total,bordes = np.histogram(data,bins=5)
print(total)
print(bordes)
# Out:
# [ 17 271 527 178   7]
# [-3.75722763 -2.20088779 -0.64454794  0.9117919   2.46813175  4.02447159]

# %%
#Histograma de dos dimensiones
mean = [0,0]
cov = [[1,1],[1,2]]
x,y = np.random.multivariate_normal(mean, cov,10000).T


plt.hist2d(x,y,bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('total por contenedor')

# %%
plt.hexbin(x,y,gridsize=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('total por contenedor')

# %%
totales, x_bordes,y_bordes = np.histogram2d(x,y,bins=10)
totales
# Out:
# array([[4.000e+00, 2.000e+00, 3.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#        [8.000e+00, 2.700e+01, 4.400e+01, 1.900e+01, 3.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#        [5.000e+00, 5.200e+01, 1.610e+02, 1.630e+02, 6.200e+01, 9.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00],
#        [1.000e+00, 4.500e+01, 2.840e+02, 6.250e+02, 3.890e+02, 8.200e+01,
#         1.200e+01, 0.000e+00, 0.000e+00, 0.000e+00],
#        [0.000e+00, 1.200e+01, 2.000e+02, 8.150e+02, 1.060e+03, 4.430e+02,
#         7.700e+01, 3.000e+00, 0.000e+00, 0.000e+00],
#        [1.000e+00, 1.000e+00, 5.900e+01, 3.830e+02, 1.103e+03, 9.050e+02,
#         2.720e+02, 2.500e+01, 1.000e+00, 0.000e+00],
#        [0.000e+00, 0.000e+00, 5.000e+00, 7.100e+01, 4.720e+02, 7.190e+02,
#         4.410e+02, 9.400e+01, 5.000e+00, 0.000e+00],
#        [0.000e+00, 0.000e+00, 0.000e+00, 6.000e+00, 6.200e+01, 2.310e+02,
# ...

# %%
x_bordes
# Out:
# array([-3.81277748, -3.07043618, -2.32809487, -1.58575357, -0.84341226,
#        -0.10107096,  0.64127035,  1.38361165,  2.12595296,  2.86829426,
#         3.61063557])

# %%
y_bordes
# Out:
# array([-5.30123229, -4.15924627, -3.01726024, -1.87527422, -0.7332882 ,
#         0.40869783,  1.55068385,  2.69266987,  3.83465589,  4.97664192,
#         6.11862794])

# %%
data = np.random.multivariate_normal(mean,cov,1000)
sns.kdeplot(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt 
import numpy as np 

mean = [0,0]
cov = [[1,1],[1,2]]

x,y = np.random.multivariate_normal(mean,cov,1000).T
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
hist,x_b,y_b = np.histogram2d(x,y,bins=40, range=[[-4,4],[-4,4]])
xpos, ypos = np.meshgrid(x_bordes[:-1]+0.25,y_bordes[:-1]+0.25, indexing='ij')
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0 

dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos,ypos,zpos, dx,dy,dz,zsort='average')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-da96f39cc073> in <module>()
#      17 dz = hist.ravel()
#      18
# ---> 19 ax.bar3d(xpos,ypos,zpos, dx,dy,dz,zsort='average')
#
# /usr/local/lib/python3.7/dist-packages/mpl_toolkits/mplot3d/axes3d.py in bar3d(self, x, y, z, dx, dy, dz, color, zsort, shade, lightsource, *args, **kwargs)
#    2363
#    2364         x, y, z, dx, dy, dz = np.broadcast_arrays(
# -> 2365             np.atleast_1d(x), y, z, dx, dy, dz)
#    2366         minx = np.min(x)
#    2367         maxx = np.max(x + dx)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
# ...
